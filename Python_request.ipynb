# %%
import pandas as pd
import requests

# %%
# base uri for the api request 
base_uri = "https://swapi.dev/api/"

# make the api request for
responce = requests.get(base_uri).json()
responce
# Out:
# {'people': 'https://swapi.dev/api/people/',
#  'planets': 'https://swapi.dev/api/planets/',
#  'films': 'https://swapi.dev/api/films/',
#  'species': 'https://swapi.dev/api/species/',
#  'vehicles': 'https://swapi.dev/api/vehicles/',
#  'starships': 'https://swapi.dev/api/starships/'}

# %% [markdown]
# 1. Using the code from the lesson as a guide and the REST API from https://swapi.dev/ as we did in the lesson, create a dataframe named people that has all of the data for people.

# %%
people = requests.get(responce['people']).json()
people
# Out:
# {'count': 82,
#  'next': 'https://swapi.dev/api/people/?page=2',
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#    'height': '172',
#    'mass': '77',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '19BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.dev/api/planets/1/',
#    'films': ['https://swapi.dev/api/films/1/',
#     'https://swapi.dev/api/films/2/',
#     'https://swapi.dev/api/films/3/',
#     'https://swapi.dev/api/films/6/'],
#    'species': [],
#    'vehicles': ['https://swapi.dev/api/vehicles/14/',
#     'https://swapi.dev/api/vehicles/30/'],
#    'starships': ['https://swapi.dev/api/starships/12/',
#     'https://swapi.dev/api/starships/22/'],
#    'created': '2014-12-09T13:50:51.644000Z',
#    'edited': '2014-12-20T21:17:56.891000Z',
#    'url': 'https://swapi.dev/api/people/1/'},
#   {'name': 'C-3PO',
#    'height': '167',
#    'mass': '75',
#    'hair_color': 'n/a',
# ...

# %%
people.keys()
# Out:
# dict_keys(['count', 'next', 'previous', 'results'])

# %%
# make a dataframe of the results
people_df = pd.DataFrame(people["results"])
people_df.head()
# Out:
#              name height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker    172   77      blond         fair      blue      19BBY
# 1           C-3PO    167   75        n/a         gold    yellow     112BBY
# 2           R2-D2     96   32        n/a  white, blue       red      33BBY
# 3     Darth Vader    202  136       none        white    yellow    41.9BBY
# 4     Leia Organa    150   49      brown        light     brown      19BBY
#
#    gender                         homeworld  \
# 0    male  https://swapi.dev/api/planets/1/
# 1     n/a  https://swapi.dev/api/planets/1/
# 2     n/a  https://swapi.dev/api/planets/8/
# 3    male  https://swapi.dev/api/planets/1/
# 4  female  https://swapi.dev/api/planets/2/
#
#                                                films  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...
# 1  [https://swapi.dev/api/films/1/, https://swapi...
# 2  [https://swapi.dev/api/films/1/, https://swapi...
# ...

# %%
number_of_people = people['count']
next_page = people['next']
previous_page = people['previous']

print(f'number_of_people: {number_of_people}')
print(f'next_page: {next_page}')
print(f'previous_page: {previous_page}')
# Out:
# number_of_people: 82
# next_page: https://swapi.dev/api/people/?page=2
# previous_page: None

# %% [markdown]
# **Get all people**

# %%
# add every person raw to the people df
while people["next"] != None:
    people = requests.get(people["next"]).json()
    people_df = pd.concat([people_df, pd.DataFrame(people["results"])]).reset_index(drop=True)

# %%
people_df.shape
# Out:
# (82, 16)

# %%
# explod the columns with lists
people_df = people_df.explode(column="films")
people_df = people_df.explode(column="species")
people_df = people_df.explode(column="vehicles")
people_df = people_df.explode(column="starships")

# %%
people_df.shape
# Out:
# (226, 16)

# %% [markdown]
# **2. Do the same thing, but for planets.**

# %%
planets = requests.get(responce['planets']).json()

# %%
planets.keys()
# Out:
# dict_keys(['count', 'next', 'previous', 'results'])

# %%
planets_df = pd.DataFrame(planets["results"])
planets_df.head()
# Out:
#        name rotation_period orbital_period diameter              climate  \
# 0  Tatooine              23            304    10465                 arid
# 1  Alderaan              24            364    12500            temperate
# 2  Yavin IV              24           4818    10200  temperate, tropical
# 3      Hoth              23            549     7200               frozen
# 4   Dagobah              23            341     8900                murky
#
#         gravity                             terrain surface_water  population  \
# 0    1 standard                              desert             1      200000
# 1    1 standard               grasslands, mountains            40  2000000000
# 2    1 standard                 jungle, rainforests             8        1000
# 3  1.1 standard  tundra, ice caves, mountain ranges           100     unknown
# 4           N/A                      swamp, jungles             8     unknown
#
#                                            residents  \
# ...

# %%
# add every person raw to the people df
while planets["next"] != None:
    planets = requests.get(planets["next"]).json()
    planets_df = pd.concat([planets_df, pd.DataFrame(planets["results"])]).reset_index(drop=True)

# %%
planets_df.shape
# Out:
# (60, 14)

# %%
# explod the columns with lists
planets_df = planets_df.explode(column="residents")
planets_df = planets_df.explode(column="films")

# %%
planets_df.shape
# Out:
# (180, 14)

# %% [markdown]
# **3. Extract the data for starships.**

# %%
starships = requests.get(responce['starships']).json()

# %%
starships.keys()
# Out:
# dict_keys(['count', 'next', 'previous', 'results'])

# %%
starships_df = pd.DataFrame(starships["results"])
starships_df.head()
# Out:
#                            name                            model  \
# 0                 CR90 corvette                    CR90 corvette
# 1                Star Destroyer  Imperial I-class Star Destroyer
# 2  Sentinel-class landing craft     Sentinel-class landing craft
# 3                    Death Star      DS-1 Orbital Battle Station
# 4             Millennium Falcon          YT-1300 light freighter
#
#                                         manufacturer cost_in_credits  length  \
# 0                  Corellian Engineering Corporation         3500000     150
# 1                                   Kuat Drive Yards       150000000   1,600
# 2            Sienar Fleet Systems, Cyngus Spaceworks          240000      38
# 3  Imperial Department of Military Research, Sien...   1000000000000  120000
# 4                  Corellian Engineering Corporation          100000   34.37
#
#   max_atmosphering_speed     crew passengers cargo_capacity consumables  \
# ...

# %%
# add every person raw to the people df
while starships["next"] != None:
    starships = requests.get(starships["next"]).json()
    starships_df = pd.concat([starships_df, pd.DataFrame(starships["results"])]).reset_index(drop=True)

# %%
starships_df.shape
# Out:
# (36, 18)

# %%
# explod the columns with lists
starships_df = starships_df.explode(column="films")
starships_df = starships_df.explode(column="pilots")

# %%
starships_df.shape
# Out:
# (87, 18)

# %% [markdown]
# ### Merge all three data frames and save

# %%
star_plan = pd.merge(left=planets_df, right=planets_df, how="left", on="url")
star_plan.head(2)
# Out:
#      name_x rotation_period_x orbital_period_x diameter_x climate_x  \
# 0  Tatooine                23              304      10465      arid
# 1  Tatooine                23              304      10465      arid
#
#     gravity_x terrain_x surface_water_x population_x  \
# 0  1 standard    desert               1       200000
# 1  1 standard    desert               1       200000
#
#                        residents_x  ... diameter_y climate_y   gravity_y  \
# 0  https://swapi.dev/api/people/1/  ...      10465      arid  1 standard
# 1  https://swapi.dev/api/people/1/  ...      10465      arid  1 standard
#
#   terrain_y surface_water_y population_y                      residents_y  \
# 0    desert               1       200000  https://swapi.dev/api/people/1/
# 1    desert               1       200000  https://swapi.dev/api/people/1/
#
#                           films_y                    created_y  \
# 0  https://swapi.dev/api/films/1/  2014-12-09T13:50:49.641000Z
# ...

# %%
# final merge
starwar = pd.merge(left=star_plan, right=people_df, how="inner", left_on="url", right_on="homeworld")
starwar.head(3)
# Out:
#      name_x rotation_period_x orbital_period_x diameter_x climate_x  \
# 0  Tatooine                23              304      10465      arid
# 1  Tatooine                23              304      10465      arid
# 2  Tatooine                23              304      10465      arid
#
#     gravity_x terrain_x surface_water_x population_x  \
# 0  1 standard    desert               1       200000
# 1  1 standard    desert               1       200000
# 2  1 standard    desert               1       200000
#
#                        residents_x  ... birth_year gender  \
# 0  https://swapi.dev/api/people/1/  ...      19BBY   male
# 1  https://swapi.dev/api/people/1/  ...      19BBY   male
# 2  https://swapi.dev/api/people/1/  ...      19BBY   male
#
#                           homeworld                           films species  \
# 0  https://swapi.dev/api/planets/1/  https://swapi.dev/api/films/1/     NaN
# 1  https://swapi.dev/api/planets/1/  https://swapi.dev/api/films/1/     NaN
# ...

# %%
# save to csv
starwar.to_csv("./starwar.csv")
print("saved")
# Out:
# saved

# %% [markdown]
# **Acquire the Open Power Systems Data for Germany, which has been rapidly expanding its renewable energy production in recent years. The data set includes country-wide totals of electricity consumption, wind power production, and solar power production for 2006-2017. You can get the data here: https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv**

# %%
powerSys = pd.read_csv("https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv")
powerSys
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 0     2006-01-01   1069.18400      NaN     NaN         NaN
# 1     2006-01-02   1380.52100      NaN     NaN         NaN
# 2     2006-01-03   1442.53300      NaN     NaN         NaN
# 3     2006-01-04   1457.21700      NaN     NaN         NaN
# 4     2006-01-05   1477.13100      NaN     NaN         NaN
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]
